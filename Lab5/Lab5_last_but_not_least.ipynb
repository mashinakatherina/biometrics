# %%
import pandas as pd
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
execution_path = os.getcwd()
execution_path
# Out:
# 'C:\\Катерина\\2 Курс\\Биометрия\\Lab5'

# %%
image = Image.open(execution_path + "/rhythms.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=623x477 at 0x60D1550>

# %%
image = Image.open(execution_path + "/alpha.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=955x549 at 0x60D14C0>

# %% [markdown]
# МЮ-РИТМЫ (сенсомоторные ритмы)
#
# Мю-ритм (Mu rhythm) – ритм в полосе частот 8-13 Гц, представляющий собой аркообразные волны, регистрируемые в центральных и центрально-височных регионах скальпа в состоянии бодрствования. Амплитуда различна, но обычно ниже 50 мкВ. Наиболее явно блокируется или ослабляется контрлатеральными движениями, мысленным представлением движений, состоянием готовности к движению или тактильной стимуляцией. Обозначается греческой буквой µ. Синонимы: аркоидные (arceau), аркообразные (wicket), гребенчатые ритмы. Сенсомоторные ритмы имеют немного более высокую частоту, чем затылочные альфа-ритмы.
#
# Мю-ритмы, фрагмент электроэнцефалограммы. ЭЭГ, зарегистрированная у здорового взрослого субъекта в течение спокойного бодрствования с открытыми глазами.

# %%
from pyedflib import highlevel

# %%
signals_1, signal_headers_1, header_1 = highlevel.read_edf('Subject00_1.edf')
signals_2, signal_headers_2, header_2 = highlevel.read_edf('Subject00_2.edf')

# %%
image = Image.open(execution_path + "/detektors.gif")
image
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=316x305 at 0x60D1928>

# %%
s1_o1 = np.fft.fft(signals_1[14])
s1_o2 = np.fft.fft(signals_1[15])
s2_o1 = np.fft.fft(signals_2[14])
s2_o2 = np.fft.fft(signals_2[15])

s1_p3 = np.fft.fft(signals_1[12])
s1_p4 = np.fft.fft(signals_1[13])
s2_p3 = np.fft.fft(signals_2[12])
s2_p4 = np.fft.fft(signals_2[13])
#O1 - 14, O2 - 15
#P3 - 12, P4 - 13

# %%
#500 отметок в секунду
i=0
for s in s1_o1:
    i +=1
print('Датчик О1 запись 1 имеет ',i, ' данных')
i=0
for s in s1_o2:
    i +=1
print('Датчик О2 запись 1 имеет ',i, ' данных')
i=0
for s in s2_o1:
    i +=1
print('Датчик О1 запись 2 имеет ',i, ' данных')
i=0
for s in s2_o2:
    i +=1
print('Датчик О2 запись 2 имеет ',i, ' данных')

i=0
for s in s1_p3:
    i +=1
print('Датчик p3 запись 1 имеет ',i, ' данных')
i=0
for s in s1_p4:
    i +=1
print('Датчик p4 запись 1 имеет ',i, ' данных')
i=0
for s in s2_p3:
    i +=1
print('Датчик p3 запись 2 имеет ',i, ' данных')
i=0
for s in s2_p4:
    i +=1
print('Датчик p4 запись 2 имеет ',i, ' данных')
# Out:
# Датчик О1 запись 1 имеет  91000  данных
# Датчик О2 запись 1 имеет  91000  данных
# Датчик О1 запись 2 имеет  31000  данных
# Датчик О2 запись 2 имеет  31000  данных
# Датчик p3 запись 1 имеет  91000  данных
# Датчик p4 запись 1 имеет  91000  данных
# Датчик p3 запись 2 имеет  31000  данных
# Датчик p4 запись 2 имеет  31000  данных

# %%
so11 = abs(s1_o1)
so12 = abs(s1_o2)
so21 = abs(s2_o1)
so22 = abs(s2_o2)

sp13 = abs(s1_p3)
sp14 = abs(s1_p4)
sp23 = abs(s2_p3)
sp24 = abs(s2_p4)

# %%
plt.plot(so11[0:13000])


plt.grid()
title = plt.title('Запись 1 датчик О1', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[0:2000])


plt.grid()
title = plt.title('датчик О1.1', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[2001:4000])


plt.grid()
title = plt.title('датчик О1.2', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[4001:6000])


plt.grid()
title = plt.title('датчик О1.3', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[6001:8000])


plt.grid()
title = plt.title('датчик О1.4', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[8001:10000])


plt.grid()
title = plt.title('датчик О1.5', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[10001:12000])


plt.grid()
title = plt.title('датчик О1.6', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so11[12001:14000])


plt.grid()
title = plt.title('датчик О1.6', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so12[0:13000])


plt.grid()
title = plt.title('Запись 1, датчик О2', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so21[0:5000])


plt.grid()
title = plt.title('Запись 2, датчик О1', fontweight="bold")
x_label = plt.xlabel('заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(so22[0:5000])


plt.grid()
title = plt.title('Запись 2 датчик O2', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(sp13[0:13000])


plt.grid()
title = plt.title('Запись 1, датчик P3', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(sp14[0:13000])


plt.grid()
title = plt.title('Запись 1, датчик P4', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(sp23[0:5000])


plt.grid()
title = plt.title('Запись 2, датчик P3', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
plt.plot(sp24[0:5000])


plt.grid()
title = plt.title('Запись 2 датчик p4', fontweight="bold")
x_label = plt.xlabel('Заметка', fontsize=12)
y_label = plt.ylabel('мкВ', fontsize=12)

# %%
# частота = скорость / длинна волны
def findalpha (s,n):
    v = 500
    tmp = np.arange(n, dtype = float)
    lam = 0
    i=0
    flag = 0
    counter = 0
    j = 0
    for i in range(n):
        if (abs(s [i]) >= 60 and abs(s[i]) <= 140):
            if (abs(s[i-1])<=100 and abs(s[i]) >= 100):
                if (flag % 2 == 0):
                    flag += 1
                    lam = i -lam
                    tmp[j] = v / lam
                    j += 1
                    counter += 1
                
                else:
                    flag += 1
    return tmp

# %%
tmp = findalpha(s1_o1, 91000)

print('Запись 1, датчик О1:')
for i in range(91000):
    if (tmp[i] >= 8 and tmp[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',tmp[i])
# Out:
# Запись 1, датчик О1:
# Интервал  4  - Альфа интервал с часотой:  10.0
# Интервал  6  - Альфа интервал с часотой:  8.19672131147541

# %%
a = findalpha(s1_o2, 91000)

print('Запись 1, датчик О2:')
for i in range(206):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 1, датчик О2:

# %%
a = findalpha(s2_o1, 31000)

print('Запись 2, датчик О1:')
for i in range(31000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 2, датчик О1:
# Интервал  2  - Альфа интервал с часотой:  8.333333333333334

# %%
a = findalpha(s2_o2, 31000)

print('Запись 2, датчик О2:')
for i in range(31000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 2, датчик О2:
# Интервал  4  - Альфа интервал с часотой:  12.195121951219512
# Интервал  6  - Альфа интервал с часотой:  9.433962264150944

# %%
a = findalpha(s1_p3, 91000)

print('Запись 1, датчик P3:')
for i in range(91000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 1, датчик P3:

# %%
a = findalpha(s1_p4, 91000)

print('Запись 1, датчик P4:')
for i in range(91000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 1, датчик P4:

# %%
a = findalpha(s2_p3, 31000)

print('Запись 2, датчик P3:')
for i in range(31000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 2, датчик P3:

# %%
a = findalpha(s2_p4, 31000)

print('Запись 2, датчик P4:')
for i in range(31000):
    if (a[i] >= 8 and a[i] <= 14):
        print('Интервал ', (i + 1), ' - Альфа интервал с часотой: ',a[i])
# Out:
# Запись 2, датчик P4:
# Интервал  6  - Альфа интервал с часотой:  12.820512820512821
# Интервал  8  - Альфа интервал с часотой:  9.433962264150944
