# %%
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/essential-v4/hololens.zip
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# !unzip hololens.zip
# Out:
# unzip:  cannot find or open hololens.zip, hololens.zip.zip or hololens.zip.ZIP.

# %%
# !pip3 install tensorflow-gpu==1.13.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==1.13.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow-gpu==1.13.1

# %%
# !pip3 install imageai --upgrade
# Out:
# Collecting imageai
#   Downloading imageai-2.1.5-py3-none-any.whl (180 kB)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from imageai) (1.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from imageai) (3.2.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from imageai) (1.18.1)
# Collecting h5py
#   Downloading h5py-2.10.0-cp38-cp38-win32.whl (2.1 MB)
# Collecting pillow
#   Downloading Pillow-7.1.2-cp38-cp38-win32.whl (1.8 MB)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib->imageai) (2.4.6)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib->imageai) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib->imageai) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib->imageai) (0.10.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from h5py->imageai) (1.14.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->imageai) (41.2.0)
# Installing collected packages: h5py, pillow, imageai
# Successfully installed h5py-2.10.0 imageai-2.1.5 pillow-7.1.2

# %%
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/essential-v4/hololens-ex-60--loss-2.76.h5
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/essential-v4/detection_config.json
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="hololens")
trainer.setTrainConfig(object_names_array=["hololens"], batch_size=4, num_experiments=100, train_from_pretrained_model="pretrained-yolov3.h5")
trainer.trainModel()

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="hololens")
trainer.evaluateModel(model_path="hololens/models", json_path="hololens/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)
# Out:
# Starting Model evaluation....
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Model File:  hololens/models/detection_model-ex-05--loss-4.94.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.8922
# mAP: 0.8922
# ===============================
# Model File:  hololens/models/detection_model-ex-01--loss-32.68.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.5259
# mAP: 0.5259
# ===============================
# Model File:  hololens/models/detection_model-ex-07--loss-4.25.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.9809
# mAP: 0.9809
# ===============================
# Model File:  hololens/models/detection_model-ex-04--loss-5.55.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.8336
# mAP: 0.8336
# ===============================
# Model File:  hololens/models/detection_model-ex-06--loss-4.70.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.9375
# mAP: 0.9375
# ===============================
# /usr/local/lib/python3.6/dist-packages/imageai/Detection/Custom/utils/utils.py:197: RuntimeWarning: overflow encountered in exp
#   w = anchors[2 * b + 0] * np.exp(w) / net_w # unit: image width
# Model File:  hololens/models/detection_model-ex-03--loss-7.48.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# hololens: 0.9184
# mAP: 0.9184
# ===============================

# %%
from imageai.Detection.Custom import CustomObjectDetection

detector = CustomObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath("hololens-ex-60--loss-2.76.h5") 
detector.setJsonPath("detection_config.json")
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image="holo3.jpg", output_image_path="holo3-detected.jpg")
for detection in detections:
    print(detection["name"], " : ", detection["percentage_probability"], " : ", detection["box_points"])
